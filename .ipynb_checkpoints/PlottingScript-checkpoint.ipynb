# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat

sns.set_style('ticks')

# %%
dynData = loadmat('./Data/Dynamcs.mat')

# %%
cir_on = dynData['cir_on']
cir_off = dynData['cir_off']
tspan = dynData['tspan'].flatten() / 24

# %%
traceN = cir_on.shape[1]
bPalette = sns.color_palette('winter', traceN)
rPalette = sns.color_palette('autumn', traceN)


fig, ax = plt.subplots(figsize=[3, 2])
fig.dpi = 300

for idx in range(traceN):
    ax.plot(tspan, cir_off[:, idx], color=rPalette[idx])
    ax.plot(tspan, cir_on[:, idx], color=bPalette[idx])

ax.set_yscale('symlog', linthreshy=0.001)
ax.set_xlim([0, 50])
ax.set_ylabel('Population (symlog)')
ax.set_xlabel('Time (days)')
ax.grid(True, which='both')

fig.savefig('./ExportedFigs/Dynmaics.svg')

# %%
sns.palplot(rPalette)
plt.savefig('./ExportedFigs/DynLgd1.svg')
sns.palplot(bPalette)   
plt.savefig('./ExportedFigs/DynLgd2.svg')

# %%
dynData_mut1 = loadmat('./Data/Dynamcs_mut1.mat')
dynData_mut2 = loadmat('./Data/Dynamcs_mut2.mat')

# %%
dynData_mut1
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Apr 21 17:02:40 2020',
#  '__version__': '1.0',
#  '__globals__': [],
#  'f_all': array([[1.00000000e+01, 1.00000000e-01, 0.00000000e+00],
#         [1.00613993e+01, 1.00392830e-01, 0.00000000e+00],
#         [1.01227324e+01, 1.00784482e-01, 0.00000000e+00],
#         ...,
#         [1.84428921e+01, 1.18995081e-01, 8.99318522e-03],
#         [1.84431957e+01, 1.19006517e-01, 8.98336891e-03],
#         [1.84434983e+01, 1.19017938e-01, 8.97356331e-03]]),
#  't_all': array([[0.00000000e+00],
#         [4.80480480e-01],
#         [9.60960961e-01],
#         ...,
#         [1.43903904e+03],
#         [1.43951952e+03],
#         [1.44000000e+03]])}

# %%
dynData_mut2
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Apr 21 17:02:41 2020',
#  '__version__': '1.0',
#  '__globals__': [],
#  'f_all': array([[1.00000000e+01, 1.00000000e-01, 0.00000000e+00],
#         [1.00621965e+01, 1.01194560e-01, 0.00000000e+00],
#         [1.01259197e+01, 1.02397996e-01, 0.00000000e+00],
#         ...,
#         [1.44267049e+02, 1.41878763e-08, 1.00006270e+00],
#         [1.44267120e+02, 1.40606647e-08, 1.00006095e+00],
#         [1.44267240e+02, 1.39345930e-08, 1.00005801e+00]]),
#  't_all': array([[0.00000000e+00],
#         [4.80480480e-01],
#         [9.60960961e-01],
#         ...,
#         [1.43903904e+03],
#         [1.43951952e+03],
#         [1.44000000e+03]])}
